# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sbn

# %%
df = pd.read_excel("merc.xlsx")

# %%
df
# Out:
#        year  price transmission  mileage  tax   mpg  engineSize
# 0      2005   5200    Automatic    63000  325  32.1         1.8
# 1      2017  34948    Automatic    27000   20  61.4         2.1
# 2      2016  49948    Automatic     6200  555  28.0         5.5
# 3      2016  61948    Automatic    16000  325  30.4         4.0
# 4      2016  73948    Automatic     4000  325  30.1         4.0
# ...     ...    ...          ...      ...  ...   ...         ...
# 13114  2020  35999    Automatic      500  145  55.4         2.0
# 13115  2020  24699    Automatic     2500  145  55.4         2.0
# 13116  2019  30999    Automatic    11612  145  41.5         2.1
# 13117  2019  37990    Automatic     2426  145  45.6         2.0
# 13118  2019  54999    Automatic     2075  145  52.3         2.9
#
# [13119 rows x 7 columns]

# %%
df.describe()
# Out:
#                year          price        mileage           tax           mpg  \
# count  13119.000000   13119.000000   13119.000000  13119.000000  13119.000000
# mean    2017.296288   24698.596920   21949.559037    129.972178     55.155843
# std        2.224709   11842.675542   21176.512267     65.260286     15.220082
# min     1970.000000     650.000000       1.000000      0.000000      1.100000
# 25%     2016.000000   17450.000000    6097.500000    125.000000     45.600000
# 50%     2018.000000   22480.000000   15189.000000    145.000000     56.500000
# 75%     2019.000000   28980.000000   31779.500000    145.000000     64.200000
# max     2020.000000  159999.000000  259000.000000    580.000000    217.300000
#
#          engineSize
# count  13119.000000
# mean       2.071530
# std        0.572426
# min        0.000000
# 25%        1.800000
# 50%        2.000000
# 75%        2.100000
# max        6.200000

# %% [markdown]
# ### veriyi anlamak

# %%
df.describe()
# Out:
#                year          price        mileage           tax           mpg  \
# count  13119.000000   13119.000000   13119.000000  13119.000000  13119.000000
# mean    2017.296288   24698.596920   21949.559037    129.972178     55.155843
# std        2.224709   11842.675542   21176.512267     65.260286     15.220082
# min     1970.000000     650.000000       1.000000      0.000000      1.100000
# 25%     2016.000000   17450.000000    6097.500000    125.000000     45.600000
# 50%     2018.000000   22480.000000   15189.000000    145.000000     56.500000
# 75%     2019.000000   28980.000000   31779.500000    145.000000     64.200000
# max     2020.000000  159999.000000  259000.000000    580.000000    217.300000
#
#          engineSize
# count  13119.000000
# mean       2.071530
# std        0.572426
# min        0.000000
# 25%        1.800000
# 50%        2.000000
# 75%        2.100000
# max        6.200000

# %%
df.isnull().sum()
# Out:
# year            0
# price           0
# transmission    0
# mileage         0
# tax             0
# mpg             0
# engineSize      0
# dtype: int64

# %%
plt.figure(figsize = (20,10))
sbn.distplot(df["price"])
# Out:
# C:\Users\Mervep\Anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='price', ylabel='Density'>

# %%
df.groupby("year").count()
# Out:
#       price  transmission  mileage   tax   mpg  engineSize
# year
# 1970      1             1        1     1     1           1
# 1997      1             1        1     1     1           1
# 1998      4             4        4     4     4           4
# 1999      1             1        1     1     1           1
# 2000      3             3        3     3     3           3
# 2001     10            10       10    10    10          10
# 2002      9             9        9     9     9           9
# 2003      7             7        7     7     7           7
# 2004     13            13       13    13    13          13
# 2005      9             9        9     9     9           9
# 2006      8             8        8     8     8           8
# 2007     22            22       22    22    22          22
# 2008     16            16       16    16    16          16
# 2009     17            17       17    17    17          17
# 2010     38            38       38    38    38          38
# ...

# %%
plt.figure(figsize = (20,10))
sbn.countplot(df["year"])
# Out:
# C:\Users\Mervep\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='year', ylabel='count'>

# %%
df.corr()
# Out:
#                 year     price   mileage       tax       mpg  engineSize
# year        1.000000  0.520712 -0.738027  0.012480 -0.094626   -0.142147
# price       0.520712  1.000000 -0.537214  0.268717 -0.438445    0.516126
# mileage    -0.738027 -0.537214  1.000000 -0.160223  0.202850    0.063652
# tax         0.012480  0.268717 -0.160223  1.000000 -0.513742    0.338341
# mpg        -0.094626 -0.438445  0.202850 -0.513742  1.000000   -0.339862
# engineSize -0.142147  0.516126  0.063652  0.338341 -0.339862    1.000000

# %%
df.corr()["price"].sort_values()
# Out:
# mileage      -0.537214
# mpg          -0.438445
# tax           0.268717
# engineSize    0.516126
# year          0.520712
# price         1.000000
# Name: price, dtype: float64

# %%
sbn.scatterplot(x = "mileage",y = "price",data = df)
# Out:
# <AxesSubplot:xlabel='mileage', ylabel='price'>

# %%
dfNew = df.sort_values("price",ascending = False).iloc[131:]

# %%
dfNew
# Out:
#        year  price transmission  mileage  tax   mpg  engineSize
# 6177   2019  65990    Semi-Auto     5076  150  30.4         3.0
# 5779   2020  65990    Semi-Auto      999  145  28.0         4.0
# 3191   2020  65980    Semi-Auto     3999  145  28.0         4.0
# 4727   2019  65000    Semi-Auto     3398  145  27.2         4.0
# 8814   2019  64999    Semi-Auto      119  145  40.9         3.0
# ...     ...    ...          ...      ...  ...   ...         ...
# 11549  2002   1495    Automatic    13800  305  39.8         2.7
# 12594  2004   1495       Manual   119000  300  34.5         1.8
# 11765  2000   1490    Automatic    87000  265  27.2         3.2
# 12008  2010   1350       Manual   116126  145  54.3         2.0
# 11816  2003    650       Manual   109090  235  40.0         1.4
#
# [12988 rows x 7 columns]

# %%
plt.figure(figsize = (20,10))
sbn.distplot(dfNew["price"])
# Out:
# C:\Users\Mervep\Anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='price', ylabel='Density'>

# %%
df.groupby("year").mean()["price"] # yıllara göre gruplandırıp, her yıl için ortalamsını aldık
# Out:
# year
# 1970    24999.000000
# 1997     9995.000000
# 1998     8605.000000
# 1999     5995.000000
# 2000     5743.333333
# 2001     4957.900000
# 2002     5820.444444
# 2003     4878.000000
# 2004     4727.615385
# 2005     4426.111111
# 2006     4036.875000
# 2007     5136.045455
# 2008     6967.437500
# 2009     6166.764706
# 2010     8308.473684
# 2011    12624.894737
# 2012    10845.140351
# 2013    11939.842466
# 2014    14042.936864
# 2015    16731.780020
# 2016    19307.892948
# 2017    21514.307854
# 2018    25720.162918
# 2019    31290.020865
# 2020    35433.282337
# Name: price, dtype: float64

# %%
df[df.year != 1970].groupby("year").mean()["price"]
# Out:
# year
# 1997     9995.000000
# 1998     8605.000000
# 1999     5995.000000
# 2000     5743.333333
# 2001     4957.900000
# 2002     5820.444444
# 2003     4878.000000
# 2004     4727.615385
# 2005     4426.111111
# 2006     4036.875000
# 2007     5136.045455
# 2008     6967.437500
# 2009     6166.764706
# 2010     8308.473684
# 2011    12624.894737
# 2012    10845.140351
# 2013    11939.842466
# 2014    14042.936864
# 2015    16731.780020
# 2016    19307.892948
# 2017    21514.307854
# 2018    25720.162918
# 2019    31290.020865
# 2020    35433.282337
# Name: price, dtype: float64

# %%
df[(df["year"]==1970)]
# Out:
#        year  price  mileage  tax   mpg  engineSize
# 12072  1970  24999    14000  305  39.2         0.0

# %%
df = df.drop("transmission",axis = 1)

# %%
df
# Out:
#        year  price  mileage  tax   mpg  engineSize
# 0      2005   5200    63000  325  32.1         1.8
# 1      2017  34948    27000   20  61.4         2.1
# 2      2016  49948     6200  555  28.0         5.5
# 3      2016  61948    16000  325  30.4         4.0
# 4      2016  73948     4000  325  30.1         4.0
# ...     ...    ...      ...  ...   ...         ...
# 13114  2020  35999      500  145  55.4         2.0
# 13115  2020  24699     2500  145  55.4         2.0
# 13116  2019  30999    11612  145  41.5         2.1
# 13117  2019  37990     2426  145  45.6         2.0
# 13118  2019  54999     2075  145  52.3         2.9
#
# [13119 rows x 6 columns]

# %%
y = df["price"].values

# %%
x = df.drop("price",axis = 1)

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.3,random_state = 10)

# %%
x_train
# Out:
#        year  mileage  tax   mpg  engineSize
# 5967   2018     6361  145  56.5         2.1
# 3913   2018     8400  145  57.7         2.0
# 1638   2016    35991   30  64.2         2.1
# 4714   2019     5501  145  36.7         2.0
# 5217   2020      859  145  32.1         2.0
# ...     ...      ...  ...   ...         ...
# 11633  2019    21118  150  37.2         2.0
# 1344   2016    22433   20  74.3         1.5
# 12815  2019    11190  150  56.5         2.1
# 7293   2019     5738  145  53.3         1.3
# 1289   2018    23061  145  67.3         2.1
#
# [9183 rows x 5 columns]

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()

# %%
x_train = scaler.fit_transform(x_train)
x_test = scaler.fit_transform(x_test)

# %%
from tensorflow.keras.models import Sequential

# %%
x_train.shape
# Out:
# (9183, 5)

# %%
model = Sequential()
model.add(Dense(12,activation="relu"))
model.add(Dense(12,activation="relu"))
model.add(Dense(12,activation="relu"))
model.add(Dense(12,activation="relu"))

model.add(Dense(1))

# %%
model.compile(optimizer="adam",loss = "mse")

# %%
model.fit(x = x_train, y = y_train, epochs=300, 
          validation_data = (x_test,y_test),
         batch_size = 250)
# Out:
# Epoch 1/300
# 37/37 [==============================] - 1s 12ms/step - loss: 741840256.0000 - val_loss: 769861632.0000
# Epoch 2/300
# 37/37 [==============================] - 0s 4ms/step - loss: 741804096.0000 - val_loss: 769800192.0000
# Epoch 3/300
# 37/37 [==============================] - 0s 4ms/step - loss: 741690816.0000 - val_loss: 769601152.0000
# Epoch 4/300
# 37/37 [==============================] - 0s 4ms/step - loss: 741321152.0000 - val_loss: 768971648.0000
# Epoch 5/300
# 37/37 [==============================] - 0s 4ms/step - loss: 740239936.0000 - val_loss: 767257152.0000
# Epoch 6/300
# 37/37 [==============================] - 0s 4ms/step - loss: 737542784.0000 - val_loss: 763271104.0000
# Epoch 7/300
# 37/37 [==============================] - 0s 4ms/step - loss: 731728576.0000 - val_loss: 755167552.0000
# Epoch 8/300
# 37/37 [==============================] - 0s 4ms/step - loss: 720601600.0000 - val_loss: 740333504.0000
# Epoch 9/300
# ...

# %%
kayipVerisi = pd.DataFrame(model.history.history)

# %%
kayipVerisi
# Out:
#             loss     val_loss
# 0    741840256.0  769861632.0
# 1    741804096.0  769800192.0
# 2    741690816.0  769601152.0
# 3    741321152.0  768971648.0
# 4    740239936.0  767257152.0
# ..           ...          ...
# 295   31647936.0   36436116.0
# 296   31622362.0   36876768.0
# 297   31665742.0   36407296.0
# 298   31692672.0   36554356.0
# 299   31613320.0   38241224.0
#
# [300 rows x 2 columns]

# %%
kayipVerisi.plot()
# Out:
# <AxesSubplot:>

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error

# %%
tahminDizisi = model.predict(x_test)
# Out:
# 123/123 [==============================] - 0s 2ms/step

# %%
tahminDizisi
# Out:
# array([[37077.28 ],
#        [28334.186],
#        [37865.13 ],
#        ...,
#        [22005.396],
#        [17358.396],
#        [20430.504]], dtype=float32)

# %%
mean_absolute_error(y_test,tahminDizisi)
# Out:
# 3753.741328045605

# %%
plt.scatter(y_test,tahminDizisi)
plt.plot(y_test,y_test,"g-*")
